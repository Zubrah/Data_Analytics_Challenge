# %% [markdown]
# # ---------------------------------------Rwanda Revenue Authourity -----------------------------
#    -------------------------------------------------------------------------------Data Analytics Challenge---------------------------------------------------
#          ![RR%20Logo.png](attachment:RR%20Logo.png)

# %% [markdown]
# ## ---------------------------------------------Methodological Flow![Methodology.PNG](attachment:Methodology.PNG)

# %%
#Upload or read our data into the implementation environment (From your folder)

# %%
#Import Libraries for Data Analytics
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## STAGE 2-DATA COLLECTION

# %%
#Decide on dataset and respective source for the problem
data = pd.read_excel('revenue-allocation-kenya.xlsx')
data1 = pd.read_csv("DP_LIVE_17022021201836306.csv")
# data2 = pd.read_excel('Tax.xslx')

# %%
#Webscrapping
import requests
page = requests.get('https://www.newtimes.co.rw/')
contents = page.content
print(contents)
# Out:
# b'<!DOCTYPE html>\n<html lang="en" dir="ltr" prefix="fb: http://www.facebook.com/2008/fbml og: http://ogp.me/ns# rnews: http://iptc.org/std/rNews/2011-10-07# content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema# schema: http://schema.org/">\n<head>\n\n    <link rel="profile" href="http://www.w3.org/1999/xhtml/vocab"/>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <!--[if lt IE 9]>\n    <script src="https://oss.maxcdn.com/html5shiv/3.7.3/html5shiv.min.js"></script>\n    <![endif]-->\n    <!-- Twitter Cards -->\n    <meta name="twitter:card" content="summary_large_image">\n    <meta name="twitter:site" content="@NewTime
# ...

# %%
#Conduct an initial feature checks (head and tail of the data )
data.head(3) #Focusing on data number 1 from Kenya
#data1.head(3)
# Out:
#   Unnamed: 0 Equitable Share Total Allocations  Allocation_x000D_Ratio  \
# 0     County      FY 2018/19        FY 2019/20                     NaN
# 1    Baringo      4940384400        5778725715                    1.62
# 2      Bomet      5763781800        6680554474                    1.89
#
#   Level-5 Hospitals  Compensation for_x000D_user fees foregone  \
# 0               NaN                                        NaN
# 1                 -                                 13191000.0
# 2                 -                                 16713356.0
#
#    Rehabiliation of_x000D_Village Polytechnics  \
# 0                                          NaN
# 1                                   35605000.0
# 2                                   47875000.0
#
#    Road Maintenance_x000D_Levy Fund  Leasing of Medical_x000D_Equipment  \
# 0                               NaN                                 NaN
# 1                       145541813.0                         131914894.0
# ...

# %%
data.tail(1)
# Out:
#      Unnamed: 0 Equitable Share Total Allocations  Allocation_x000D_Ratio  \
# 48  GRAND TOTAL    304962000000      367443384193                   100.0
#
#    Level-5 Hospitals  Compensation for_x000D_user fees foregone  \
# 48        4455780000                                900000000.0
#
#     Rehabiliation of_x000D_Village Polytechnics  \
# 48                                 2.000000e+09
#
#     Road Maintenance_x000D_Levy Fund  Leasing of Medical_x000D_Equipment  \
# 48                      8.984062e+09                        6.200000e+09
#
#    Supplement for_x000D_construction of county_x000D_headquarters  \
# 48                                          605000000
#
#     Loans & Grants  Total Allocations.1  Per capita_x000D_allocation (Kshs)  \
# 48    3.853829e+10         3.716831e+11                             12000.0
#
#     Equitable Share.1
# 48       3.100000e+11

# %% [markdown]
# ### Check the state of the data

# %%
data.dtypes
# Out:
# Unnamed: 0                                               object
# Equitable Share                                          object
# Total Allocations                                        object
# Allocation\rRatio                                       float64
# Level-5 Hospitals                                        object
# Compensation for\ruser fees foregone                    float64
# Rehabiliation of\rVillage Polytechnics                  float64
# Road Maintenance\rLevy Fund                             float64
# Leasing of Medical\rEquipment                           float64
# Supplement for\rconstruction of county\rheadquarters     object
# Loans & Grants                                          float64
# Total Allocations.1                                     float64
# Per capita\rallocation (Kshs)                           float64
# Equitable Share.1                                       float64
# dtype: object

# %%
data.shape
# Out:
# (49, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 14 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Unnamed: 0                                          49 non-null     object
#  1   Equitable Share                                     49 non-null     object
#  2   Total Allocations                                   49 non-null     object
# Ratio                                    48 non-null     float64
#  4   Level-5 Hospitals                                   48 non-null     object
# user fees foregone                 48 non-null     float64
# Village Polytechnics               48 non-null     float64
# Levy Fund                          48 non-null     float64
# Equipment                        48 non-null     float64
# headquarters  48 non-null     object
# ...

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# dtype: bool

# %% [markdown]
# ### Describing Data

# %%
data.describe()
# Out:
#        Allocation\rRatio  Compensation for\ruser fees foregone  \
# count          48.000000                          4.800000e+01
# mean            4.166667                          3.750000e+07
# std            14.147402                          1.277426e+08
# min             1.130000                          2.451034e+06
# 25%             1.570000                          1.252502e+07
# 50%             1.955000                          1.806758e+07
# 75%             2.627500                          2.357171e+07
# max           100.000000                          9.000000e+08
#
#        Rehabiliation of\rVillage Polytechnics  Road Maintenance\rLevy Fund  \
# count                            4.800000e+01                 4.800000e+01
# mean                             8.333333e+07                 3.743359e+08
# std                              2.828745e+08                 1.271011e+09
# min                              2.090500e+07                 1.015199e+08
# ...

# %%
data.nunique()
# Out:
# Unnamed: 0                                              49
# Equitable Share                                         45
# Total Allocations                                       49
# Allocation\rRatio                                       44
# Level-5 Hospitals                                       12
# Compensation for\ruser fees foregone                    48
# Rehabiliation of\rVillage Polytechnics                  48
# Road Maintenance\rLevy Fund                             44
# Leasing of Medical\rEquipment                            2
# Supplement for\rconstruction of county\rheadquarters     3
# Loans & Grants                                          48
# Total Allocations.1                                     48
# Per capita\rallocation (Kshs)                           48
# Equitable Share.1                                       44
# dtype: int64

# %% [markdown]
# ### Renaming specific column

# %%
data.head(1)
# Out:
#   Unnamed: 0 Equitable Share Total Allocations  Allocation\rRatio  \
# 0     County      FY 2018/19        FY 2019/20                NaN
#
#   Level-5 Hospitals  Compensation for\ruser fees foregone  \
# 0               NaN                                   NaN
#
#    Rehabiliation of\rVillage Polytechnics  Road Maintenance\rLevy Fund  \
# 0                                     NaN                          NaN
#
#    Leasing of Medical\rEquipment  \
# 0                            NaN
#
#   Supplement for\rconstruction of county\rheadquarters  Loans & Grants  \
# 0                                                NaN               NaN
#
#    Total Allocations.1  Per capita\rallocation (Kshs)  Equitable Share.1
# 0                  NaN                            NaN                NaN

# %%
data.rename(columns = {'Equitable Share': 'Shareholders'}, inplace = True)

# %%
data.head()
# Out:
#   Unnamed: 0 Shareholders Total Allocations  Allocation\rRatio  \
# 0     County   FY 2018/19        FY 2019/20                NaN
# 1    Baringo   4940384400        5778725715               1.62
# 2      Bomet   5763781800        6680554474               1.89
# 3    Bungoma   8691417000        9998082441               2.85
# 4      Busia   5794278000        6744720378               1.90
#
#   Level-5 Hospitals  Compensation for\ruser fees foregone  \
# 0               NaN                                   NaN
# 1                 -                            13191000.0
# 2                 -                            16713356.0
# 3                 -                            32837307.0
# 4                 -                            16934085.0
#
#    Rehabiliation of\rVillage Polytechnics  Road Maintenance\rLevy Fund  \
# 0                                     NaN                          NaN
# 1                              35605000.0                  145541813.0
# ...

# %%
data = data.rename(columns={'Equitable Share': 'Share', 'Total Allocations': 'Allocations'})

# %%
data.head()
# Out:
#   Unnamed: 0 Shareholders Allocations  Allocation\rRatio Level-5 Hospitals  \
# 0     County   FY 2018/19  FY 2019/20                NaN               NaN
# 1    Baringo   4940384400  5778725715               1.62                 -
# 2      Bomet   5763781800  6680554474               1.89                 -
# 3    Bungoma   8691417000  9998082441               2.85                 -
# 4      Busia   5794278000  6744720378               1.90                 -
#
#    Compensation for\ruser fees foregone  \
# 0                                   NaN
# 1                            13191000.0
# 2                            16713356.0
# 3                            32837307.0
# 4                            16934085.0
#
#    Rehabiliation of\rVillage Polytechnics  Road Maintenance\rLevy Fund  \
# 0                                     NaN                          NaN
# 1                              35605000.0                  145541813.0
# ...

# %% [markdown]
# ### STAGE 3 DATA CLEANING, PREPARATION, DATA TRANSFORMATION AND INTERGRATION

# %%
#Remove in specific rows and columns with Null/NaN values
data.drop(data.index[0])
# Out:
#          Unnamed: 0  Shareholders   Allocations  Allocation\rRatio  \
# 1           Baringo    4940384400    5778725715               1.62
# 2             Bomet    5763781800    6680554474               1.89
# 3           Bungoma    8691417000    9998082441               2.85
# 4             Busia    5794278000    6744720378               1.90
# 5   Elgeyo/Marakwet    3659544000    4457455034               1.20
# 6              Embu    4330460400    5421155761               1.42
# 7           Garissa    6739660200    9134942947               2.21
# 8          Homa Bay    6495690600    7419924616               2.13
# 9            Isiolo    3812025000    4685826269               1.25
# 10          Kajiado    5824774200    6812115049               1.91
# 11         Kakamega   10033249800   11888141665               3.29
# 12          Kericho    5550308400    6517000071               1.82
# 13           Kiambu    9087867600   12406684614               2.98
# ...

# %%
#keep top 3
data[:3]
# Out:
#   Unnamed: 0 Shareholders Allocations  Allocation\rRatio Level-5 Hospitals  \
# 0     County   FY 2018/19  FY 2019/20                NaN               NaN
# 1    Baringo   4940384400  5778725715               1.62                 -
# 2      Bomet   5763781800  6680554474               1.89                 -
#
#    Compensation for\ruser fees foregone  \
# 0                                   NaN
# 1                            13191000.0
# 2                            16713356.0
#
#    Rehabiliation of\rVillage Polytechnics  Road Maintenance\rLevy Fund  \
# 0                                     NaN                          NaN
# 1                              35605000.0                  145541813.0
# 2                              47875000.0                  169798781.0
#
#    Leasing of Medical\rEquipment  \
# 0                            NaN
# 1                    131914894.0
# 2                    131914894.0
#
# ...

# %%
data[:3]
# Out:
#   Unnamed: 0 Shareholders Allocations  Allocation\rRatio Level-5 Hospitals  \
# 0     County   FY 2018/19  FY 2019/20                NaN               NaN
# 1    Baringo   4940384400  5778725715               1.62                 -
# 2      Bomet   5763781800  6680554474               1.89                 -
#
#    Compensation for\ruser fees foregone  \
# 0                                   NaN
# 1                            13191000.0
# 2                            16713356.0
#
#    Rehabiliation of\rVillage Polytechnics  Road Maintenance\rLevy Fund  \
# 0                                     NaN                          NaN
# 1                              35605000.0                  145541813.0
# 2                              47875000.0                  169798781.0
#
#    Leasing of Medical\rEquipment  \
# 0                            NaN
# 1                    131914894.0
# 2                    131914894.0
#
# ...

# %%
#drop bottom 3 
data[:-3]
# Out:
#          Unnamed: 0 Shareholders  Allocations  Allocation\rRatio  \
# 0            County   FY 2018/19   FY 2019/20                NaN
# 1           Baringo   4940384400   5778725715               1.62
# 2             Bomet   5763781800   6680554474               1.89
# 3           Bungoma   8691417000   9998082441               2.85
# 4             Busia   5794278000   6744720378               1.90
# 5   Elgeyo/Marakwet   3659544000   4457455034               1.20
# 6              Embu   4330460400   5421155761               1.42
# 7           Garissa   6739660200   9134942947               2.21
# 8          Homa Bay   6495690600   7419924616               2.13
# 9            Isiolo   3812025000   4685826269               1.25
# 10          Kajiado   5824774200   6812115049               1.91
# 11         Kakamega  10033249800  11888141665               3.29
# 12          Kericho   5550308400   6517000071               1.82
# ...

# %%
#Remove in specific rows and columns with Null/NaN values
data.dropna()
# Out:
#          Unnamed: 0  Shareholders   Allocations  Allocation\rRatio  \
# 1           Baringo    4940384400    5778725715               1.62
# 2             Bomet    5763781800    6680554474               1.89
# 3           Bungoma    8691417000    9998082441               2.85
# 4             Busia    5794278000    6744720378               1.90
# 5   Elgeyo/Marakwet    3659544000    4457455034               1.20
# 6              Embu    4330460400    5421155761               1.42
# 7           Garissa    6739660200    9134942947               2.21
# 8          Homa Bay    6495690600    7419924616               2.13
# 9            Isiolo    3812025000    4685826269               1.25
# 10          Kajiado    5824774200    6812115049               1.91
# 11         Kakamega   10033249800   11888141665               3.29
# 12          Kericho    5550308400    6517000071               1.82
# 13           Kiambu    9087867600   12406684614               2.98
# ...

# %%
data.head()
# Out:
#   Unnamed: 0 Shareholders Allocations  Allocation\rRatio Level-5 Hospitals  \
# 0     County   FY 2018/19  FY 2019/20                NaN               NaN
# 1    Baringo   4940384400  5778725715               1.62                 -
# 2      Bomet   5763781800  6680554474               1.89                 -
# 3    Bungoma   8691417000  9998082441               2.85                 -
# 4      Busia   5794278000  6744720378               1.90                 -
#
#    Compensation for\ruser fees foregone  \
# 0                                   NaN
# 1                            13191000.0
# 2                            16713356.0
# 3                            32837307.0
# 4                            16934085.0
#
#    Rehabiliation of\rVillage Polytechnics  Road Maintenance\rLevy Fund  \
# 0                                     NaN                          NaN
# 1                              35605000.0                  145541813.0
# ...

# %%
data.drop(['Allocation\rRatio'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-42135df86109> in <module>
# ----> 1 data.drop(['Allocation\rRatio'], axis = 1)
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4303                 weight  1.0     0.8
#    4304         """
# -> 4305         return super().drop(
#    4306             labels=labels,
#    4307             axis=axis,
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4150         for axis, labels in axes.items():
#    4151             if labels is not None:
# -> 4152                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4153
#    4154         if inplace:
#
# ...

# %%
#Select specific columns
data[['Shareholders', 'Leasing of Medical\rEquipment']]
# Out:
#     Shareholders  Leasing of Medical\rEquipment
# 0     FY 2018/19                            NaN
# 1     4940384400                   1.319149e+08
# 2     5763781800                   1.319149e+08
# 3     8691417000                   1.319149e+08
# 4     5794278000                   1.319149e+08
# 5     3659544000                   1.319149e+08
# 6     4330460400                   1.319149e+08
# 7     6739660200                   1.319149e+08
# 8     6495690600                   1.319149e+08
# 9     3812025000                   1.319149e+08
# 10    5824774200                   1.319149e+08
# 11   10033249800                   1.319149e+08
# 12    5550308400                   1.319149e+08
# 13    9087867600                   1.319149e+08
# 14   10521189000                   1.319149e+08
# 15    3995002200                   1.319149e+08
# 16    7471569000                   1.319149e+08
# 17    6709164000                   1.319149e+08
# 18    8477943600                   1.319149e+08
# ...

# %%
#Select specific range of columns
data[data.columns[2:4]]
# Out:
#      Allocations  Allocation\rRatio
# 0     FY 2019/20                NaN
# 1     5778725715               1.62
# 2     6680554474               1.89
# 3     9998082441               2.85
# 4     6744720378               1.90
# 5     4457455034               1.20
# 6     5421155761               1.42
# 7     9134942947               2.21
# 8     7419924616               2.13
# 9     4685826269               1.25
# 10    6812115049               1.91
# 11   11888141665               3.29
# 12    6517000071               1.82
# 13   12406684614               2.98
# 14   12215750837               3.45
# 15    4742094252               1.31
# 16    8979452357               2.45
# 17    8783717505               2.20
# 18    9613793830               2.78
# 19    8647570910               2.40
# 20    4783508025               1.31
# 21    4243607344               1.13
# 22   10333845617               2.65
# 23    7920572018               2.27
# 24   10960277905               3.23
# ...

# %%
#select specific rows and columns using iloc function (df.loc[rows, columns])
data.iloc[:, 1:2]
# Out:
#     Shareholders
# 0     FY 2018/19
# 1     4940384400
# 2     5763781800
# 3     8691417000
# 4     5794278000
# 5     3659544000
# 6     4330460400
# 7     6739660200
# 8     6495690600
# 9     3812025000
# 10    5824774200
# 11   10033249800
# 12    5550308400
# 13    9087867600
# 14   10521189000
# 15    3995002200
# 16    7471569000
# 17    6709164000
# 18    8477943600
# 19    7319088000
# 20    3995002200
# 21    3446070600
# 22    8081493000
# 23    6922637400
# 24    9850272600
# 25    6800652600
# 26    7776531000
# 27    6526186800
# 28    7990004400
# 29    6068743800
# 30   15339588600
# 31    9179356200
# 32    5214850200
# 33    6190728600
# 34    4635422400
# 35    4787903400
# 36    4879392000
# 37    4299964200
# 38    5855270400
# 39    3934009800
# 40    5397827400
# 41    3537559200
# 42    5458819800
# 43   10460196600
# 44    5763781800
# 45    4330460400
# 46    8233974000
# 47    4787903400
# 48  304962000000

# %%
#Replacing everything with mean, mode median
data.fillna(data.mean())
# Out:
#          Unnamed: 0  Shareholders   Allocations  Allocation\rRatio  \
# 0            County    FY 2018/19    FY 2019/20           4.166667
# 1           Baringo    4940384400    5778725715           1.620000
# 2             Bomet    5763781800    6680554474           1.890000
# 3           Bungoma    8691417000    9998082441           2.850000
# 4             Busia    5794278000    6744720378           1.900000
# 5   Elgeyo/Marakwet    3659544000    4457455034           1.200000
# 6              Embu    4330460400    5421155761           1.420000
# 7           Garissa    6739660200    9134942947           2.210000
# 8          Homa Bay    6495690600    7419924616           2.130000
# 9            Isiolo    3812025000    4685826269           1.250000
# 10          Kajiado    5824774200    6812115049           1.910000
# 11         Kakamega   10033249800   11888141665           3.290000
# 12          Kericho    5550308400    6517000071           1.820000
# ...

# %%
data = data.replace('-',0) 
data.head(10)
# Out:
#         Unnamed: 0 Shareholders Allocations  Allocation\rRatio  \
# 0           County   FY 2018/19  FY 2019/20                NaN
# 1          Baringo   4940384400  5778725715               1.62
# 2            Bomet   5763781800  6680554474               1.89
# 3          Bungoma   8691417000  9998082441               2.85
# 4            Busia   5794278000  6744720378               1.90
# 5  Elgeyo/Marakwet   3659544000  4457455034               1.20
# 6             Embu   4330460400  5421155761               1.42
# 7          Garissa   6739660200  9134942947               2.21
# 8         Homa Bay   6495690600  7419924616               2.13
# 9           Isiolo   3812025000  4685826269               1.25
#
#    Level-5 Hospitals  Compensation for\ruser fees foregone  \
# 0                NaN                                   NaN
# 1                0.0                            13191000.0
# 2                0.0                            16713356.0
# ...

# %% [markdown]
# #### CONCATENATE DIFFERENT DATASETS (DATA AND DATA2) USING A  CONCAT() FUNCTION

# %%
data.head(2)
# Out:
#   Unnamed: 0 Shareholders Allocations  Allocation\rRatio  Level-5 Hospitals  \
# 0     County   FY 2018/19  FY 2019/20                NaN                NaN
# 1    Baringo   4940384400  5778725715               1.62                0.0
#
#    Compensation for\ruser fees foregone  \
# 0                                   NaN
# 1                            13191000.0
#
#    Rehabiliation of\rVillage Polytechnics  Road Maintenance\rLevy Fund  \
# 0                                     NaN                          NaN
# 1                              35605000.0                  145541813.0
#
#    Leasing of Medical\rEquipment  \
# 0                            NaN
# 1                    131914894.0
#
#    Supplement for\rconstruction of county\rheadquarters  Loans & Grants  \
# 0                                                NaN                NaN
# 1                                                0.0        322825892.0
#
# ...

# %%
data2.head(2)
# Out:
#         Date                                           Headline   Category
# 0  1/14/2018                  madiro faces revolt in manicaland  Political
# 1  1/14/2018  kadzuras wife demands share before estate is w...     Social

# %%
result = pd.concat([data, data2], axis=1)

# %%
result.head(1)
# Out:
#   Unnamed: 0 Shareholders Allocations  Allocation\rRatio  Level-5 Hospitals  \
# 0     County   FY 2018/19  FY 2019/20                NaN                NaN
#
#    Compensation for\ruser fees foregone  \
# 0                                   NaN
#
#    Rehabiliation of\rVillage Polytechnics  Road Maintenance\rLevy Fund  \
# 0                                     NaN                          NaN
#
#    Leasing of Medical\rEquipment  \
# 0                            NaN
#
#    Supplement for\rconstruction of county\rheadquarters  Loans & Grants  \
# 0                                                NaN                NaN
#
#    Total Allocations.1  Per capita\rallocation (Kshs)  Equitable Share.1  \
# 0                  NaN                            NaN                NaN
#
#         Date                           Headline   Category
# 0  1/14/2018  madiro faces revolt in manicaland  Political

# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS (EDA)

# %%
#Histogram graph to show frequency distributions in a bar set-up
data.hist(figsize=(20,20))
plt.show()
# Out:
# C:\Users\usr\AppData\Roaming\Python\Python38\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\usr\AppData\Roaming\Python\Python38\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#Histogram graph to show frequency distributions in a bar set-up
data.plot()
plt.ylabel('XXXXXXXXXXXXX')
# Out:
# Text(0, 0.5, 'XXXXXXXXXXXXX')
# C:\Users\usr\AppData\Roaming\Python\Python38\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\usr\AppData\Roaming\Python\Python38\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#Bar Graph
data.plot(kind='bar')
plt.ylabel('XXXXXXXXXX')
# Out:
# Text(0, 0.5, 'XXXXXXXXXX')

# %%
#Density plot show the probability density function of the variable in form of  probability distribution.
data.plot(kind='density', subplots=True, layout=(4,4), sharex=False,figsize=(15,20))
plt.show()
# Out:
# C:\Users\usr\AppData\Roaming\Python\Python38\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\usr\AppData\Roaming\Python\Python38\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#Seaborn show  visualizing the relationships between the feature
import seaborn as sns
sns.pairplot(data)
# Out:
# C:\Users\usr\AppData\Roaming\Python\Python38\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\usr\AppData\Roaming\Python\Python38\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#Line plot
lines = data.plot.line(x='Allocation\rRatio', y='Leasing of Medical\rEquipment')
# Out:
# C:\Users\usr\AppData\Roaming\Python\Python38\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\usr\AppData\Roaming\Python\Python38\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0, flags=flags)
